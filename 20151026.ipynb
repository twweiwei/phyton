# %%
joke='秉豪','豪','夢遊仙境'

# %%
joke_join=','.join(joke)
print('笑話:',joke_join)
# Out:
# 笑話: 秉豪,豪,夢遊仙境

# %%
import requests
novel=requests.get("http://www.novelscape.net/wg/g/genaidinei/jlyx/001.htm")
novel.encoding="big5"
a=novel.text
word="你"
a.count(word)
# Out:
# 10

# %%
len(a)
# Out:
# 8141

# %%
list('cat')
# Out:
# ['c', 'a', 't']

# %%
a_tuple=('ready','fire','aim')
list(a_tuple)
# Out:
# ['ready', 'fire', 'aim']

# %%
story=[[['ㄅ','ㄆ','ㄇ'],'ㄈ'],'ㄉ']
story[0][0][0]
# Out:
# 'ㄅ'

# %%
story[1]
# Out:
# 'ㄉ'
